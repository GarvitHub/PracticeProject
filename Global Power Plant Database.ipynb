# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score, confusion_matrix,roc_curve, roc_auc_score
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv')

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   907.000000  861.000000  861.000000          0.0          527.000000
# mean    326.223755   21.197918   77.464907          NaN         1997.091082
# std     590.085456    6.239612    4.939316          NaN           17.082868
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.725000   16.773900   74.256200          NaN         1988.000000
# 50%      59.200000   21.780000   76.719500          NaN         2001.000000
# 75%     385.250000   25.512400   79.440800          NaN         2012.000000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  519.0                  0.0
# mean       NaN                 2019.0                  NaN
# std        NaN                    0.0                  NaN
# ...

# %%
df.drop(columns=['other_fuel3','wepp_id','generation_gwh_2013','generation_gwh_2019','estimated_generation_gwh'],inplace=True)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  commissioning_year  \
# count   907.000000  861.000000  861.000000          527.000000
# mean    326.223755   21.197918   77.464907         1997.091082
# std     590.085456    6.239612    4.939316           17.082868
# min       0.000000    8.168900   68.644700         1927.000000
# 25%      16.725000   16.773900   74.256200         1988.000000
# 50%      59.200000   21.780000   76.719500         2001.000000
# 75%     385.250000   25.512400   79.440800         2012.000000
# max    4760.000000   34.649000   95.408000         2018.000000
#
#        year_of_capacity_data  generation_gwh_2014  generation_gwh_2015  \
# count                  519.0           398.000000           422.000000
# mean                  2019.0          2431.823590          2428.226946
# std                      0.0          4026.440035          4194.596959
# min                   2019.0             0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                   46
# longitude                  46
# primary_fuel                0
# other_fuel1               709
# other_fuel2               906
# commissioning_year        380
# owner                     565
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     388
# generation_gwh_2014       509
# generation_gwh_2015       485
# generation_gwh_2016       473
# generation_gwh_2017       467
# generation_gwh_2018       459
# generation_data_source    458
# dtype: int64

# %% [raw]
# Now, I think we have to remove those columns which has null value which are above 200 null values.

# %%
df.drop(columns=['other_fuel1','other_fuel2','owner','year_of_capacity_data','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018','generation_data_source','commissioning_year'])
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  \
# 0            2.5   28.1839    73.2407        Solar
# 1           98.0   24.7663    74.6090         Coal
# ...

# %% [raw]
# There is no use of url in this.So, let's do something

# %%
df.drop(columns=['url'])
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df.drop(columns=['other_fuel1','other_fuel2','owner','year_of_capacity_data','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018','generation_data_source','commissioning_year','url'],inplace=True)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  \
# 0            2.5   28.1839    73.2407        Solar
# 1           98.0   24.7663    74.6090         Coal
# ...

# %%
df['country'].value_counts()
# Out:
# IND    907
# Name: country, dtype: int64

# %%
df['country_long'].value_counts()
# Out:
# India    907
# Name: country_long, dtype: int64

# %% [raw]
# when both have same type of data then why can't we remove it.Let's remove it.

# %%
df.drop(columns=['country'],inplace=True)

# %%
df
# Out:
#     country_long                          name   gppd_idnr  capacity_mw  \
# 0          India              ACME Solar Tower  WRI1020239          2.5
# 1          India           ADITYA CEMENT WORKS  WRI1019881         98.0
# 2          India      AES Saurashtra Windfarms  WRI1026669         39.2
# 3          India                   AGARTALA GT  IND0000001        135.0
# 4          India                  AKALTARA TPP  IND0000002       1800.0
# ..           ...                           ...         ...          ...
# 902        India                  YERMARUS TPP  IND0000513       1600.0
# 903        India  Yelesandra Solar Power Plant  WRI1026222          3.0
# 904        India  Yelisirur wind power project  WRI1026776         25.5
# 905        India                   ZAWAR MINES  WRI1019901         80.0
# 906        India       iEnergy Theni Wind Farm  WRI1026761         16.5
#
#      latitude  longitude primary_fuel                                source  \
# ...

# %%
df.isnull().sum()
# Out:
# country_long           0
# name                   0
# gppd_idnr              0
# capacity_mw            0
# latitude              46
# longitude             46
# primary_fuel           0
# source                 0
# geolocation_source    19
# dtype: int64

# %%
df['latitude']=df['latitude'].fillna(df['latitude'].mean())

# %%
df['longitude']=df['longitude'].fillna(df['longitude'].mean())

# %%
df['geolocation_source']=df['geolocation_source'].fillna(df['geolocation_source'].mode())

# %%
df.isnull().sum()
# Out:
# country_long           0
# name                   0
# gppd_idnr              0
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# source                 0
# geolocation_source    19
# dtype: int64

# %%
df['geolocation_source'].value_counts()
# Out:
# WRI                                     765
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %%
df['geolocation_source']=df['geolocation_source'].fillna(df['geolocation_source'].mode())

# %%
df.isnull().sum()
# Out:
# country_long           0
# name                   0
# gppd_idnr              0
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# source                 0
# geolocation_source    19
# dtype: int64

# %%
df.dropna(subset=['geolocation_source'],inplace=True)

# %%
df.isnull().sum()
# Out:
# country_long          0
# name                  0
# gppd_idnr             0
# capacity_mw           0
# latitude              0
# longitude             0
# primary_fuel          0
# source                0
# geolocation_source    0
# dtype: int64

# %%
df
# Out:
#     country_long                          name   gppd_idnr  capacity_mw  \
# 0          India              ACME Solar Tower  WRI1020239          2.5
# 1          India           ADITYA CEMENT WORKS  WRI1019881         98.0
# 2          India      AES Saurashtra Windfarms  WRI1026669         39.2
# 3          India                   AGARTALA GT  IND0000001        135.0
# 4          India                  AKALTARA TPP  IND0000002       1800.0
# ..           ...                           ...         ...          ...
# 902        India                  YERMARUS TPP  IND0000513       1600.0
# 903        India  Yelesandra Solar Power Plant  WRI1026222          3.0
# 904        India  Yelisirur wind power project  WRI1026776         25.5
# 905        India                   ZAWAR MINES  WRI1019901         80.0
# 906        India       iEnergy Theni Wind Farm  WRI1026761         16.5
#
#      latitude  longitude primary_fuel                                source  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['country_long']=le.fit_transform(df['country_long'])

# %%
df.drop(columns=['name'],inplace=True)

# %%
df.drop(columns=['gppd_idnr'],inplace=True)

# %%
df['source'].value_counts()
# Out:
# Central Electricity Authority                                  519
# CDM                                                            109
# Lancosola                                                       10
# National Thermal Power Corporation (NTPC)                        6
# National Renewable Energy Laboratory                             4
#                                                               ...
# Harsha Engineers Limited                                         1
# Godawari Energy ltd                                              1
# Sunkon Energy Private Limited                                    1
# West Bengal Energy Development Corporation Limited (WBEDCL)      1
# Yashwantrao Krishna ssk                                          1
# Name: source, Length: 191, dtype: int64

# %%
df['primary_fuel']=le.fit_transform(df['primary_fuel'])

# %%
df['geolocation_source']=le.fit_transform(df['geolocation_source'])

# %%
df
# Out:
#      country_long  capacity_mw  latitude  longitude  primary_fuel  \
# 0               0          2.5   28.1839    73.2407             6
# 1               0         98.0   24.7663    74.6090             1
# 2               0         39.2   21.9038    69.3732             7
# 3               0        135.0   23.8712    91.3602             2
# 4               0       1800.0   21.9603    82.4091             1
# ..            ...          ...       ...        ...           ...
# 902             0       1600.0   16.2949    77.3568             1
# 903             0          3.0   12.8932    78.1654             6
# 904             0         25.5   15.2758    75.5811             7
# 905             0         80.0   24.3500    73.7477             1
# 906             0         16.5    9.9344    77.4768             7
#
#                                    source  geolocation_source
# 0    National Renewable Energy Laboratory                   1
# ...

# %%
df['source']=le.fit_transform(df['source'])

# %%
df
# Out:
#      country_long  capacity_mw  latitude  longitude  primary_fuel  source  \
# 0               0          2.5   28.1839    73.2407             6     109
# 1               0         98.0   24.7663    74.6090             1     174
# 2               0         39.2   21.9038    69.3732             7      21
# 3               0        135.0   23.8712    91.3602             2      22
# 4               0       1800.0   21.9603    82.4091             1      22
# ..            ...          ...       ...        ...           ...     ...
# 902             0       1600.0   16.2949    77.3568             1      22
# 903             0          3.0   12.8932    78.1654             6      77
# 904             0         25.5   15.2758    75.5811             7      21
# 905             0         80.0   24.3500    73.7477             1      59
# 906             0         16.5    9.9344    77.4768             7      21
#
#      geolocation_source
# 0                     1
# 1                     2
# ...

# %%
xr=df.drop(columns=['capacity_mw'])
yr=df['capacity_mw']

# %%
xc=df.drop(columns=['primary_fuel'])
yc=df['primary_fuel']

# %%
scaler=StandardScaler()
xr_scaled=scaler.fit_transform(xr)

# %%
xc_scaled=scaler.fit_transform(xc)

# %%
xr_train,xr_test,yr_train,yr_test=train_test_split(xr_scaled,yr,test_size=0.25,random_state=2646)

# %%
xc_train,xc_test,yc_train,yc_test=train_test_split(xc_scaled,yc,test_size=0.25,random_state=464)

# %%
lr=LinearRegression()
lr.fit(xr_train,yr_train)
# Out:
# LinearRegression()

# %%
lr.score(xr_train,yr_train)
# Out:
# 0.2064479047170965

# %%
lr.score(xr_test,yr_test)
# Out:
# 0.19102514000171267

# %%
yr_pred=lr.predict(xr_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(yr_test,yr_pred)
# Out:
# 320.5185189852249

# %%
mean_squared_error(yr_test,yr_pred)
# Out:
# 211723.56433754112

# %%
np.sqrt(mean_squared_error(yr_test,yr_pred))
# Out:
# 460.1342894607411

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(xc_train,yc_train)
# Out:
# DecisionTreeClassifier()

# %%
yc_pred=dt.predict(xc_test)

# %%
acc=accuracy_score(yc_test,yc_pred)
acc
# Out:
# 0.7972972972972973

# %%
print(classification_report(yc_test,yc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86        18
#            1       0.75      0.69      0.72        67
#            2       0.53      0.64      0.58        14
#            3       0.82      0.86      0.84        69
#            4       0.00      0.00      0.00         1
#            5       0.14      0.17      0.15         6
#            6       1.00      1.00      1.00        25
#            7       1.00      1.00      1.00        22
#
#     accuracy                           0.80       222
#    macro avg       0.64      0.65      0.64       222
# weighted avg       0.80      0.80      0.80       222
