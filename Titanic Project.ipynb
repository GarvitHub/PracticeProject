# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
new_survived= pd.Categorical(df["Survived"])
new_survived= new_survived.rename_categories(["Died","Survived"])
new_survived.describe()
# Out:
#             counts     freqs
# categories
# Died           549  0.616162
# Survived       342  0.383838

# %%
df["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
new_Pclass= pd.Categorical(df["Pclass"], ordered=True)
new_Pclass= new_Pclass.rename_categories(["Class 1","Class 2", "Class 3"])
new_Pclass.describe()
# Out:
#             counts     freqs
# categories
# Class 1        216  0.242424
# Class 2        184  0.206510
# Class 3        491  0.551066

# %%
df["Pclass"]= new_Pclass

# %%
df
# Out:
#      PassengerId  Survived   Pclass  \
# 0              1         0  Class 3
# 1              2         1  Class 1
# 2              3         1  Class 3
# 3              4         1  Class 1
# 4              5         0  Class 3
# ..           ...       ...      ...
# 886          887         0  Class 2
# 887          888         1  Class 1
# 888          889         0  Class 3
# 889          890         1  Class 1
# 890          891         0  Class 3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df["Survived"]= new_survived

# %%
df
# Out:
#      PassengerId  Survived   Pclass  \
# 0              1      Died  Class 3
# 1              2  Survived  Class 1
# 2              3  Survived  Class 3
# 3              4  Survived  Class 1
# 4              5      Died  Class 3
# ..           ...       ...      ...
# 886          887      Died  Class 2
# 887          888  Survived  Class 1
# 888          889      Died  Class 3
# 889          890  Survived  Class 1
# 890          891      Died  Class 3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
missing = np.where(df["Age"].isnull()==True)

# %%
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
#         839, 846, 849, 859, 863, 868, 878, 888], dtype=int64),)

# %%
df.loc[missing]
# Out:
#      PassengerId  Survived   Pclass                                      Name  \
# 5              6      Died  Class 3                          Moran, Mr. James
# 17            18  Survived  Class 2              Williams, Mr. Charles Eugene
# 19            20  Survived  Class 3                   Masselmani, Mrs. Fatima
# 26            27      Died  Class 3                   Emir, Mr. Farred Chehab
# 28            29  Survived  Class 3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...      ...                                       ...
# 859          860      Died  Class 3                          Razi, Mr. Raihed
# 863          864      Died  Class 3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869      Died  Class 3               van Melkebeke, Mr. Philemon
# 878          879      Died  Class 3                        Laleff, Mr. Kristo
# 888          889      Died  Class 3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 17     male  NaN      0      0      244373  13.0000   NaN        S
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %%
df.corr()
# Out:
#              PassengerId       Age     SibSp     Parch      Fare
# PassengerId     1.000000  0.036847 -0.057527 -0.001652  0.012658
# Age             0.036847  1.000000 -0.308247 -0.189119  0.096067
# SibSp          -0.057527 -0.308247  1.000000  0.414838  0.159651
# Parch          -0.001652 -0.189119  0.414838  1.000000  0.216225
# Fare            0.012658  0.096067  0.159651  0.216225  1.000000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Le= LabelEncoder()

# %%
df["Pclass"].value_counts()
# Out:
# Class 3    491
# Class 1    216
# Class 2    184
# Name: Pclass, dtype: int64

# %%
df["Survived"].value_counts()
# Out:
# Died        549
# Survived    342
# Name: Survived, dtype: int64

# %%
mean_method=df["Age"].mean()

# %%
df["Age"].fillna(value=mean_method)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df
# Out:
#      PassengerId  Survived   Pclass  \
# 0              1      Died  Class 3
# 1              2  Survived  Class 1
# 2              3  Survived  Class 3
# 3              4  Survived  Class 1
# 4              5      Died  Class 3
# ..           ...       ...      ...
# 886          887      Died  Class 2
# 887          888  Survived  Class 1
# 888          889      Died  Class 3
# 889          890  Survived  Class 1
# 890          891      Died  Class 3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
#         839, 846, 849, 859, 863, 868, 878, 888], dtype=int64),)

# %%
df.loc[missing]
# Out:
#      PassengerId  Survived   Pclass                                      Name  \
# 5              6      Died  Class 3                          Moran, Mr. James
# 17            18  Survived  Class 2              Williams, Mr. Charles Eugene
# 19            20  Survived  Class 3                   Masselmani, Mrs. Fatima
# 26            27      Died  Class 3                   Emir, Mr. Farred Chehab
# 28            29  Survived  Class 3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...      ...                                       ...
# 859          860      Died  Class 3                          Razi, Mr. Raihed
# 863          864      Died  Class 3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869      Died  Class 3               van Melkebeke, Mr. Philemon
# 878          879      Died  Class 3                        Laleff, Mr. Kristo
# 888          889      Died  Class 3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 17     male  NaN      0      0      244373  13.0000   NaN        S
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %%
df["Age"].fillna(value=mean_method, inplace=True)

# %%
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
#         839, 846, 849, 859, 863, 868, 878, 888], dtype=int64),)

# %%
df.loc[missing]
# Out:
#      PassengerId  Survived   Pclass                                      Name  \
# 5              6      Died  Class 3                          Moran, Mr. James
# 17            18  Survived  Class 2              Williams, Mr. Charles Eugene
# 19            20  Survived  Class 3                   Masselmani, Mrs. Fatima
# 26            27      Died  Class 3                   Emir, Mr. Farred Chehab
# 28            29  Survived  Class 3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...      ...                                       ...
# 859          860      Died  Class 3                          Razi, Mr. Raihed
# 863          864      Died  Class 3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869      Died  Class 3               van Melkebeke, Mr. Philemon
# 878          879      Died  Class 3                        Laleff, Mr. Kristo
# 888          889      Died  Class 3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex        Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  29.699118      0      0      330877   8.4583   NaN        Q
# 17     male  29.699118      0      0      244373  13.0000   NaN        S
# 19   female  29.699118      0      0        2649   7.2250   NaN        C
# 26     male  29.699118      0      0        2631   7.2250   NaN        C
# 28   female  29.699118      0      0      330959   7.8792   NaN        Q
# ..      ...        ...    ...    ...         ...      ...   ...      ...
# 859    male  29.699118      0      0        2629   7.2292   NaN        C
# 863  female  29.699118      8      2    CA. 2343  69.5500   NaN        S
# 868    male  29.699118      0      0      345777   9.5000   NaN        S
# 878    male  29.699118      0      0      349217   7.8958   NaN        S
# 888  female  29.699118      1      2  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %%
df
# Out:
#      PassengerId  Survived   Pclass  \
# 0              1      Died  Class 3
# 1              2  Survived  Class 1
# 2              3  Survived  Class 3
# 3              4  Survived  Class 1
# 4              5      Died  Class 3
# ..           ...       ...      ...
# 886          887      Died  Class 2
# 887          888  Survived  Class 1
# 888          889      Died  Class 3
# 889          890  Survived  Class 1
# 890          891      Died  Class 3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df["Survived"].value_counts()
# Out:
# Died        549
# Survived    342
# Name: Survived, dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# Class 3    491
# Class 1    216
# Class 2    184
# Name: Pclass, dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Sex"]=Le.fit_transform(df["Sex"])

# %%
df["Survived"]=Le.fit_transform(df["Survived"])

# %%
df["Pclass"]=Le.fit_transform(df["Pclass"])

# %%
df["Embarked"]=Le.fit_transform(df["Embarked"])

# %%
df["Sex"].value_counts()
# Out:
# 1    577
# 0    314
# Name: Sex, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df["Cabin"]
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df["Cabin"].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
df.drop(["Cabin"],axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       2
# 1              2         1       0
# 2              3         1       2
# 3              4         1       0
# 4              5         0       2
# ..           ...       ...     ...
# 886          887         0       1
# 887          888         1       0
# 888          889         0       2
# 889          890         1       0
# 890          891         0       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ..                                                 ...  ...        ...    ...
# 886                              Montvila, Rev. Juozas    1  27.000000      0
# 887                       Graham, Miss. Margaret Edith    0  19.000000      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    0  29.699118      1
# 889                              Behr, Mr. Karl Howell    1  26.000000      0
# 890                                Dooley, Mr. Patrick    1  32.000000      0
#
#      Parch            Ticket     Fare  Embarked
# 0        0         A/5 21171   7.2500         2
# 1        0          PC 17599  71.2833         0
# 2        0  STON/O2. 3101282   7.9250         2
# 3        0            113803  53.1000         2
# 4        0            373450   8.0500         2
# ..     ...               ...      ...       ...
# 886      0            211536  13.0000         2
# 887      0            112053  30.0000         2
# 888      2        W./C. 6607  23.4500         2
# 889      0            111369  30.0000         0
# 890      0            370376   7.7500         1
#
# [891 rows x 11 columns]

# %%
df.drop(["Name"],axis=1, inplace=True)

# %%
df.drop(["PassengerId"],axis=1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch            Ticket  \
# 0           0       2    1  22.000000      1      0         A/5 21171
# 1           1       0    0  38.000000      1      0          PC 17599
# 2           1       2    0  26.000000      0      0  STON/O2. 3101282
# 3           1       0    0  35.000000      1      0            113803
# 4           0       2    1  35.000000      0      0            373450
# ..        ...     ...  ...        ...    ...    ...               ...
# 886         0       1    1  27.000000      0      0            211536
# 887         1       0    0  19.000000      0      0            112053
# 888         0       2    0  29.699118      1      2        W./C. 6607
# 889         1       0    1  26.000000      0      0            111369
# 890         0       2    1  32.000000      0      0            370376
#
#         Fare  Embarked
# 0     7.2500         2
# 1    71.2833         0
# 2     7.9250         2
# 3    53.1000         2
# 4     8.0500         2
# ..       ...       ...
# 886  13.0000         2
# 887  30.0000         2
# 888  23.4500         2
# 889  30.0000         0
# 890   7.7500         1
#
# [891 rows x 9 columns]

# %%
df.corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481 -0.543351 -0.069809 -0.035322  0.081629
# Pclass   -0.338481  1.000000  0.131900 -0.331339  0.083081  0.018443
# Sex      -0.543351  0.131900  1.000000  0.084153 -0.114631 -0.245489
# Age      -0.069809 -0.331339  0.084153  1.000000 -0.232625 -0.179191
# SibSp    -0.035322  0.083081 -0.114631 -0.232625  1.000000  0.414838
# Parch     0.081629  0.018443 -0.245489 -0.179191  0.414838  1.000000
# Fare      0.257307 -0.549500 -0.182333  0.091566  0.159651  0.216225
# Embarked -0.163517  0.157112  0.104057 -0.022239  0.066654  0.038322
#
#               Fare  Embarked
# Survived  0.257307 -0.163517
# Pclass   -0.549500  0.157112
# Sex      -0.182333  0.104057
# Age       0.091566 -0.022239
# SibSp     0.159651  0.066654
# Parch     0.216225  0.038322
# Fare      1.000000 -0.221226
# Embarked -0.221226  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
    
corr_mat=df.corr().abs()
plt.figure(figsize=[20,15])
sns.heatmap(corr_mat,annot=True,annot_kws= {'size':20})
plt.title("correlation Matrix")
plt.show()

# %%
x=df.drop(columns=['Survived'])
y=df['Survived']

# %%
x
# Out:
#      Pclass  Sex        Age  SibSp  Parch            Ticket     Fare  Embarked
# 0         2    1  22.000000      1      0         A/5 21171   7.2500         2
# 1         0    0  38.000000      1      0          PC 17599  71.2833         0
# 2         2    0  26.000000      0      0  STON/O2. 3101282   7.9250         2
# 3         0    0  35.000000      1      0            113803  53.1000         2
# 4         2    1  35.000000      0      0            373450   8.0500         2
# ..      ...  ...        ...    ...    ...               ...      ...       ...
# 886       1    1  27.000000      0      0            211536  13.0000         2
# 887       0    0  19.000000      0      0            112053  30.0000         2
# 888       2    0  29.699118      1      2        W./C. 6607  23.4500         2
# 889       0    1  26.000000      0      0            111369  30.0000         0
# 890       2    1  32.000000      0      0            370376   7.7500         1
#
# [891 rows x 8 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int32

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings('ignore')

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size= 0.25, random_state= 40)

# %%
clf= DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [77], in <cell line: 2>()
#       1 clf= DecisionTreeClassifier()
# ----> 2 clf.fit(x_train,y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:165, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 165 X, y = self._validate_data(
#     166     X, y, validate_separately=(check_X_params, check_y_params)
#     167 )
#     168 if issparse(X):
#     169     X.sort_indices()
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:578, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     572 if validate_separately:
#     573     # We need this because some estimators validate X and y
#     574     # separately, and in general, separately calling check_array()
#     575     # on X and y isn't equivalent to just calling check_X_y()
#     576     # :(
#     577     check_X_params, check_y_params = validate_separately
# --> 578     X = check_array(X, **check_X_params)
#     579     y = check_array(y, **check_y_params)
#     580 else:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Fa 265302'

# %%
x.drop(["Ticket"],axis=1, inplace=True)

# %%
x
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         2    1  22.000000      1      0   7.2500         2
# 1         0    0  38.000000      1      0  71.2833         0
# 2         2    0  26.000000      0      0   7.9250         2
# 3         0    0  35.000000      1      0  53.1000         2
# 4         2    1  35.000000      0      0   8.0500         2
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       1    1  27.000000      0      0  13.0000         2
# 887       0    0  19.000000      0      0  30.0000         2
# 888       2    0  29.699118      1      2  23.4500         2
# 889       0    1  26.000000      0      0  30.0000         0
# 890       2    1  32.000000      0      0   7.7500         1
#
# [891 rows x 7 columns]

# %%
clf= DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [80], in <cell line: 2>()
#       1 clf= DecisionTreeClassifier()
# ----> 2 clf.fit(x_train,y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:165, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 165 X, y = self._validate_data(
#     166     X, y, validate_separately=(check_X_params, check_y_params)
#     167 )
#     168 if issparse(X):
#     169     X.sort_indices()
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:578, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     572 if validate_separately:
#     573     # We need this because some estimators validate X and y
#     574     # separately, and in general, separately calling check_array()
#     575     # on X and y isn't equivalent to just calling check_X_y()
#     576     # :(
#     577     check_X_params, check_y_params = validate_separately
# --> 578     X = check_array(X, **check_X_params)
#     579     y = check_array(y, **check_y_params)
#     580 else:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Fa 265302'

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size= 0.25, random_state= 40)

# %%
clf= DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(x_train,y_train)
# Out:
# 0.9820359281437125

# %%
y_pred= clf.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7757847533632287
